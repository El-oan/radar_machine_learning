# %% [markdown]
# # PointNet for RadHAR
# Adapted to the raw GitHub dataset format with per-point features `[x, y, z, velocity, intensity]` and activity labels from the class folders.

# %%
from functools import lru_cache
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

# %%
def resolve_project_root(start_path=None):
    """Find the repository root by locating `data/Data` in the current path ancestry."""
    start_path = Path.cwd() if start_path is None else Path(start_path)
    for candidate in (start_path, *start_path.parents):
        if (candidate / 'data' / 'Data').exists():
            return candidate
    raise FileNotFoundError(
        f"Could not locate dataset folder 'data/Data' from {start_path}. "
        "Open the notebook from the repo root or `src/`, or set PROJECT_ROOT manually."
    )

PROJECT_ROOT = resolve_project_root()
DATA_ROOT = PROJECT_ROOT / 'data' / 'Data'  # Expected subfolders: Train/<class> and Test/<class>
CLASS_NAMES = ['boxing', 'jack', 'jump', 'squats', 'walk']  # Activity labels from the repo
CLASS_TO_IDX = {name: idx for idx, name in enumerate(CLASS_NAMES)}  # String label -> integer id
FEATURE_KEYS = ('x', 'y', 'z', 'velocity', 'intensity')  # Per-point features available in the raw files
FRAMES_PER_WINDOW = 60  # Two seconds at 30 FPS
WINDOW_STRIDE = 10  # Slide each training sample by 10 frames
NUM_POINTS = 32  # Fixed number of points sampled or padded per frame
BATCH_SIZE = 8  # Small batch keeps the dry run lightweight

print(f'Project root: {PROJECT_ROOT.resolve()}')
print(f'Data root: {DATA_ROOT.resolve()}')
print(f'Classes: {CLASS_NAMES}')
print(f'Point features: {FEATURE_KEYS}')
# Out:
# Project root: /Users/elo/Coding/radar_machine_learning
# Data root: /Users/elo/Coding/radar_machine_learning/data/Data
# Classes: ['boxing', 'jack', 'jump', 'squats', 'walk']
# Point features: ('x', 'y', 'z', 'velocity', 'intensity')

# %%
def parse_scalar(raw_value):
    """Convert raw text values from the ROS-style file into Python scalars."""
    raw_value = raw_value.strip().strip('"')  # Remove whitespace and optional quotes
    try:
        if any(ch in raw_value for ch in ('.', 'e', 'E')):
            return float(raw_value)  # Floating-point field like x, range, or intensity
        return int(raw_value)  # Integer field like point_id or seq
    except ValueError:
        return raw_value  # Keep non-numeric metadata as plain text

def load_radhar_file(file_path):
    """Parse one raw RadHAR text file into a list of frames of shape `(num_points, 5)`."""
    file_path = Path(file_path)
    tracked_keys = {'point_id', 'x', 'y', 'z', 'velocity', 'intensity'}  # Fields needed for PointNet
    frames = []  # Final list of frames; each frame is a variable-length point cloud
    current_frame = []  # Accumulates points until the next frame starts
    current_point = {}  # Accumulates one point record until the `---` separator

    def flush_point():
        """Finish the current point record and append it to the right frame."""
        nonlocal current_frame, current_point
        if not current_point:
            return  # Nothing to flush yet

        point_id = int(current_point.get('point_id', -1))  # `point_id: 0` marks a new frame
        if point_id == 0 and current_frame:
            frames.append(np.asarray(current_frame, dtype=np.float32))  # Close the previous frame
            current_frame = []

        feature_vector = [float(current_point.get(key, 0.0)) for key in FEATURE_KEYS]
        current_frame.append(feature_vector)  # Append one point as [x, y, z, velocity, intensity]
        current_point = {}

    with file_path.open('r') as handle:
        for raw_line in handle:
            line = raw_line.strip()  # Remove whitespace and trailing newlines
            if not line:
                continue  # Skip empty lines
            if line == '---':
                flush_point()  # End of one point record
                continue
            if ':' not in line:
                continue  # Skip malformed lines defensively

            key, raw_value = line.split(':', 1)
            key = key.strip()
            if key in tracked_keys:
                current_point[key] = parse_scalar(raw_value)  # Store only features relevant to PointNet

    flush_point()  # Finish the last point in the file
    if current_frame:
        frames.append(np.asarray(current_frame, dtype=np.float32))  # Keep the last frame too

    return frames  # List[np.ndarray], one entry per radar frame

def build_window_index(split_root, frames_per_window=60, stride=10):
    """Create `(file_path, start_frame, label_idx)` tuples for one dataset split."""
    split_root = Path(split_root)
    samples = []  # Each item points to one time window inside one recording file

    for class_name in CLASS_NAMES:
        class_dir = split_root / class_name
        for file_path in sorted(class_dir.glob('*.txt')):
            frames = load_radhar_file(str(file_path))  # Parsed once and then reused from cache
            if len(frames) < frames_per_window:
                continue  # Skip files that are too short for a full window

            max_start = len(frames) - frames_per_window
            for start_idx in range(0, max_start + 1, stride):
                samples.append((str(file_path), start_idx, CLASS_TO_IDX[class_name]))  # One labeled window

    return samples

# %%
def process_frame(points, num_points=32):
    """Convert one variable-length frame into a fixed-size point set for PointNet."""
    points = np.asarray(points, dtype=np.float32)  # Ensure the frame is a float array
    feature_dim = len(FEATURE_KEYS)  # Current PointNet input channels

    if len(points) == 0:
        return np.zeros((num_points, feature_dim), dtype=np.float32)  # Empty frame becomes all zeros

    if len(points) >= num_points:
        choice = np.random.choice(len(points), num_points, replace=False)  # Downsample dense frames
        return points[choice]  # Keep a random subset of real points only

    padded = np.zeros((num_points, feature_dim), dtype=np.float32)  # Zero-padding avoids inventing new points
    padded[:len(points)] = points  # Copy the real points into the front of the tensor
    return padded


class RadHARSequenceDataset(Dataset):
    """Serve fixed-length frame windows for activity classification."""
    def __init__(self, samples, num_points=32, frames_per_window=60):
        """Store the window index and PointNet preprocessing settings."""
        self.samples = samples  # List of `(file_path, start_idx, label_idx)` tuples
        self.num_points = num_points  # Fixed point count per frame after padding/sampling
        self.frames_per_window = frames_per_window  # Number of consecutive frames in one sample

    def __len__(self):
        """Return the total number of windows available in this split."""
        return len(self.samples)

    def __getitem__(self, idx):
        """Load one time window and return it as a `(T, C, N)` tensor with its label."""
        file_path, start_idx, label_idx = self.samples[idx]
        frames = load_radhar_file(file_path)  # Cached list of variable-length frames
        window = frames[start_idx:start_idx + self.frames_per_window]  # Consecutive radar frames
        processed_frames = [process_frame(frame, self.num_points) for frame in window]  # Each frame -> (N, C)

        sequence = np.stack(processed_frames, axis=0)  # Shape: (T, N, C)
        sequence = torch.from_numpy(sequence).float().permute(0, 2, 1)  # Shape: (T, C, N)
        label = torch.tensor(label_idx, dtype=torch.long)  # CrossEntropyLoss expects class indices
        return sequence, label

# %%
class TNet(nn.Module):
    """Learn a feature-space transform matrix that aligns each frame before encoding."""
    def __init__(self, k=5):
        """Build the mini-network that predicts a `k x k` transform matrix."""
        super().__init__()
        self.conv1 = nn.Conv1d(k, 64, 1)  # Shared MLP layer 1
        self.conv2 = nn.Conv1d(64, 128, 1)  # Shared MLP layer 2
        self.conv3 = nn.Conv1d(128, 1024, 1)  # Shared MLP layer 3
        self.fc1 = nn.Linear(1024, 512)  # Dense layer after global pooling
        self.fc2 = nn.Linear(512, 256)  # Dense bottleneck
        self.fc3 = nn.Linear(256, k * k)  # Predict the flattened transform matrix
        self.k = k  # Number of input channels/features per point

    def forward(self, x):
        """Predict one transform matrix for each sample in the batch."""
        batch_size = x.size(0)  # Number of point clouds processed in parallel
        x = F.relu(self.conv1(x))  # Shape: (B, 64, N)
        x = F.relu(self.conv2(x))  # Shape: (B, 128, N)
        x = F.relu(self.conv3(x))  # Shape: (B, 1024, N)
        x = torch.max(x, 2, keepdim=False)[0]  # Global max pooling over the point dimension
        x = F.relu(self.fc1(x))  # Shape: (B, 512)
        x = F.relu(self.fc2(x))  # Shape: (B, 256)
        x = self.fc3(x).view(batch_size, self.k, self.k)  # Shape: (B, k, k)

        identity = torch.eye(self.k, device=x.device).unsqueeze(0).repeat(batch_size, 1, 1)  # No-op bias
        return x + identity  # Start close to the identity transform for stability


class PointNetBackbone(nn.Module):
    """Encode one frame of radar points into a single 1024-D feature vector."""
    def __init__(self, input_dim=5):
        """Build the PointNet frame encoder."""
        super().__init__()
        self.tnet = TNet(k=input_dim)  # Learn to align the raw point features
        self.conv1 = nn.Conv1d(input_dim, 64, 1)  # Shared MLP layer 1
        self.conv2 = nn.Conv1d(64, 128, 1)  # Shared MLP layer 2
        self.conv3 = nn.Conv1d(128, 1024, 1)  # Shared MLP layer 3

    def forward(self, x):
        """Encode a batch of point clouds shaped `(B, C, N)` into `(B, 1024)`."""
        trans = self.tnet(x)  # Predicted alignment matrix per cloud
        x = x.transpose(2, 1)  # Shape: (B, N, C)
        x = torch.bmm(x, trans)  # Apply the learned alignment in feature space
        x = x.transpose(2, 1)  # Shape: (B, C, N)

        x = F.relu(self.conv1(x))  # Shape: (B, 64, N)
        x = F.relu(self.conv2(x))  # Shape: (B, 128, N)
        x = self.conv3(x)  # Shape: (B, 1024, N)
        x = torch.max(x, 2, keepdim=False)[0]  # PointNet's symmetric aggregation over points
        return x  # Shape: (B, 1024)


class TemporalPointNetClassifier(nn.Module):
    """Encode each frame with PointNet, then pool over time for activity recognition."""
    def __init__(self, num_classes=5, input_dim=5):
        """Build a simple temporal baseline on top of per-frame PointNet features."""
        super().__init__()
        self.frame_encoder = PointNetBackbone(input_dim=input_dim)  # Shared encoder for every frame
        self.fc1 = nn.Linear(1024, 256)  # Temporal head layer 1
        self.dropout = nn.Dropout(p=0.3)  # Mild regularization for the classifier head
        self.fc2 = nn.Linear(256, num_classes)  # Final class logits

    def forward(self, x):
        """Classify a batch shaped `(B, T, C, N)` into activity logits."""
        batch_size, num_frames, num_channels, num_points = x.shape
        x = x.view(batch_size * num_frames, num_channels, num_points)  # Flatten time into the batch axis
        frame_features = self.frame_encoder(x)  # Shape: (B * T, 1024)
        frame_features = frame_features.view(batch_size, num_frames, 1024)  # Restore the time axis

        sequence_feature = frame_features.mean(dim=1)  # Simple temporal average across the 60 frames
        x = F.relu(self.fc1(sequence_feature))  # Shape: (B, 256)
        x = self.dropout(x)  # Regularize the pooled sequence descriptor
        return self.fc2(x)  # Shape: (B, num_classes)

# %%
# Build train/test indices directly from the RadHAR folder tree.
train_samples = build_window_index(DATA_ROOT / 'Train', frames_per_window=FRAMES_PER_WINDOW, stride=WINDOW_STRIDE)
test_samples = build_window_index(DATA_ROOT / 'Test', frames_per_window=FRAMES_PER_WINDOW, stride=WINDOW_STRIDE)

print(f'Train windows: {len(train_samples)}')
print(f'Test windows: {len(test_samples)}')

if len(train_samples) == 0:
    raise ValueError(
        "No training windows were generated. "
        f"Checked path: {(DATA_ROOT / 'Train').resolve()}. "
        "Verify PROJECT_ROOT/DATA_ROOT and frames_per_window settings."
    )
if len(test_samples) == 0:
    raise ValueError(
        "No test windows were generated. "
        f"Checked path: {(DATA_ROOT / 'Test').resolve()}. "
        "Verify PROJECT_ROOT/DATA_ROOT and frames_per_window settings."
    )

# Wrap the windows in PyTorch datasets and loaders.
train_dataset = RadHARSequenceDataset(train_samples, num_points=NUM_POINTS, frames_per_window=FRAMES_PER_WINDOW)
test_dataset = RadHARSequenceDataset(test_samples, num_points=NUM_POINTS, frames_per_window=FRAMES_PER_WINDOW)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)  # Randomize batches during training
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)  # Keep evaluation deterministic

# Initialize the PointNet-based activity classifier.
model = TemporalPointNetClassifier(num_classes=len(CLASS_NAMES), input_dim=len(FEATURE_KEYS))
print('Model initialized.')

# Dry run one batch to confirm the full pipeline and tensor shapes.
sample_batch, sample_labels = next(iter(train_loader))  # One mini-batch from the real dataset
print(f'Input shape: {sample_batch.shape}')  # Expected: (B, 60, 5, NUM_POINTS)
print(f'Label shape: {sample_labels.shape}')  # Expected: (B,)

output = model(sample_batch)  # Forward pass through the temporal PointNet model
print(f'Output shape: {output.shape}')  # Expected: (B, 5)
print('Dry run successful!')
# Out:
# Train windows: 12150
# Test windows: 3565
# Model initialized.
# Input shape: torch.Size([8, 60, 5, 32])
# Label shape: torch.Size([8])
# Output shape: torch.Size([8, 5])
# Dry run successful!
