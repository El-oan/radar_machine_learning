# %% [markdown]
# # Skeletize DGUHA with SK-DGCNN
#
# This notebook applies the MARS-trained SK-DGCNN pose checkpoint to DGUHA radar clips and builds `datasets/SKDGUHA`. The cache mirrors `datasets/SKradHAR`: every raw radar clip becomes a `.pt` file containing centered 19-joint `[x, z]` skeleton frames, and `metadata.json` stores the pose contract and joint confidence scores.

# %%
from functools import lru_cache
from pathlib import Path
import json
import pickle
import shutil

import h5py
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

# %%
PROJECT_ROOT = Path('/Users/elo/Coding/radar')
MARS_ROOT = PROJECT_ROOT / 'datasets' / 'MARS'
DGUHA_ROOT = PROJECT_ROOT / 'datasets' / 'DGUHA'
SKDGUHA_ROOT = PROJECT_ROOT / 'datasets' / 'SKDGUHA'
CHECKPOINT_PATH = SKDGUHA_ROOT / 'checkpoint_133.pt'

MARS_ACTIVITY_CLASS_NAMES = (
    'Left_upper_limb_extension', 'Right_upper_limb_extension', 'Both_upper_limb_extension',
    'Left_front_lunge', 'Right_front_lunge', 'Squad', 'Left_side_lunge',
    'Right_side_lunge', 'Left_limb_extension', 'Right_limb_extension',
)
DGUHA_ACTIVITY_CLASS_NAMES = (
    'running', 'jumping', 'sitting_down_and_standing_up', 'both_upper_limb_extension',
    'falling_forward', 'right_limb_extension', 'left_limb_extension',
)
SKELETON_JOINT_NAMES = (
    'SpineBase', 'SpineMid', 'Neck', 'Head', 'ShoulderLeft', 'ElbowLeft', 'WristLeft',
    'ShoulderRight', 'ElbowRight', 'WristRight', 'HipLeft', 'KneeLeft', 'AnkleLeft',
    'FootLeft', 'HipRight', 'KneeRight', 'AnkleRight', 'FootRight', 'SpineShoulder',
)
SKELETON_JOINT_INDICES = (0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 12, 13, 14, 15, 16, 17, 18, 19, 20)
SKELETON_COORDINATE_INDICES = (0, 1)
CENTER_JOINT_INDEX = SKELETON_JOINT_NAMES.index('SpineShoulder')
RADAR_FEATURE_ROWS = {'x': 2, 'y': 3, 'z': 4, 'velocity': 5, 'intensity': 6}
MARS_RADAR_ROI = {'x': [-1.0, 1.0], 'y': [0.0, 3.0], 'z': [-1.0, 1.0]}

DEVICE = 'mps'
CONFIG = {
    'feature_names': ('x', 'y', 'z', 'velocity', 'intensity'),
    'feature_amount': 5,
    'num_points': 25,
    'clipping': 4.0,
    'validation_fraction': 0.2,
    'k': 20,
    'emb_dims': 512,
    'dropout': 0.4,
    'eca_kernel_size': 3,
    'batch_size': 64,
}

# %% [markdown]
# # MARS pose checkpoint data

# %%
def split_mars_file_paths():
    "Split MARS training recordings for pose checkpoint validation."
    train_files, valid_files = [], []
    for class_name in MARS_ACTIVITY_CLASS_NAMES:
        paths = sorted((MARS_ROOT / 'Train').glob(f'subject*/{class_name}/radar_data*.mat'))
        valid_count = max(1, int(len(paths) * CONFIG['validation_fraction']))
        valid_count = min(valid_count, len(paths) - 1)
        train_files.extend(str(path) for path in paths[:-valid_count])
        valid_files.extend(str(path) for path in paths[-valid_count:])
    return train_files, valid_files

# %%
@lru_cache(maxsize=None)
def load_mars_radar_frames_raw(file_path):
    "Load raw MARS radar frames using the features expected by SK-DGCNN."
    with h5py.File(file_path, 'r') as handle:
        radar = np.asarray(handle['radar_data_cropped'])
    frame_ids = radar[0].astype(np.int64)
    rows = [RADAR_FEATURE_ROWS[name] for name in CONFIG['feature_names']]
    features = radar[rows].T.astype(np.float32)
    return [torch.from_numpy(features[frame_ids == frame_id]) for frame_id in np.unique(frame_ids)]

# %%
@lru_cache(maxsize=None)
def load_mars_skeletons_raw(file_path):
    "Load the synchronized 19-joint Kinect targets for one MARS radar recording."
    skeleton_path = Path(str(file_path).replace('/radar_data', '/kinect_data'))
    skeletons = []
    with h5py.File(skeleton_path, 'r') as handle:
        refs = np.asarray(handle['kinect_data_cropped']['JointPositions']).ravel()
        for ref in refs:
            joints = np.asarray(handle[ref], dtype=np.float32)[0][:, SKELETON_JOINT_INDICES].T
            skeletons.append(torch.from_numpy(joints[:, SKELETON_COORDINATE_INDICES].reshape(-1)))
    return skeletons

# %%
@lru_cache(maxsize=None)
def mars_radar_normalization_stats():
    "Compute SK-DGCNN radar normalization statistics from MARS training recordings."
    train_files, _ = split_mars_file_paths()
    points = torch.cat([torch.cat(load_mars_radar_frames_raw(path), dim=0) for path in train_files], dim=0)
    return points.mean(dim=0), points.std(dim=0).clamp_min(1e-6)

# %%
def normalize_skeleton(skeleton):
    "Align Kinect lateral direction to radar and center the lateral, vertical skeleton."
    skeleton = skeleton.view(len(SKELETON_JOINT_INDICES), len(SKELETON_COORDINATE_INDICES)).clone()
    skeleton[:, 0] = -skeleton[:, 0]
    return (skeleton - skeleton[CENTER_JOINT_INDEX]).reshape(-1)

# %% [markdown]
# # DGUHA radar cache

# %%
@lru_cache(maxsize=None)
def load_dguha_points(split):
    "Load DGUHA xyz clips as frames of radar detections."
    suffix = split.lower()
    data = np.load(DGUHA_ROOT / split / f'dguha_pcl_ahc_{suffix}.npy', mmap_mode='r')[:, :, :, :, 0]
    return torch.from_numpy(np.asarray(data, dtype=np.float32).transpose(0, 2, 3, 1))

# %%
@lru_cache(maxsize=None)
def load_dguha_labels(split):
    "Load DGUHA integer activity labels."
    suffix = split.lower()
    with (DGUHA_ROOT / split / f'dguha_{suffix}_label.pkl').open('rb') as handle:
        return tuple(int(label) for label in pickle.load(handle))

# %%
def load_dguha_radar_frames_raw(split, clip_idx):
    "Load one DGUHA clip mapped to MARS coordinates with zero velocity and intensity."
    clip = load_dguha_points(split)[clip_idx]
    frames = []
    for frame in clip:
        valid = frame[frame.any(dim=1)]
        points = torch.zeros(valid.size(0), CONFIG['feature_amount'], dtype=torch.float32)
        points[:, 0] = valid[:, 1]
        points[:, 1] = valid[:, 0]
        points[:, 2] = valid[:, 2]
        frames.append(points)
    return frames

# %%
def crop_target_frame(points):
    "Restrict mapped DGUHA detections to the spatial ROI stored in local MARS radar inputs."
    return points[(points[:, 0] >= -1) & (points[:, 0] <= 1) & (points[:, 1] >= 0) & (points[:, 1] <= 3) & (points[:, 2] >= -1) & (points[:, 2] <= 1)]

# %%
def align_target_frame(points):
    "Translate a target-dataset radar frame to the MARS training spatial centroid."
    mars_mean, _ = mars_radar_normalization_stats()
    points = points.clone()
    points[:, :3] += mars_mean[:3] - points[:, :3].mean(dim=0)
    return points

# %%
def process_pose_frame(points):
    "Normalize, crop, and pad a radar frame already expressed in MARS axes."
    mean, std = mars_radar_normalization_stats()
    points = (points - mean) / std
    output = torch.zeros(CONFIG['num_points'], CONFIG['feature_amount'], dtype=torch.float32)
    output[:min(len(points), CONFIG['num_points'])] = points[:CONFIG['num_points']]
    return output

# %%
def process_target_frame(points):
    "Prepare aligned cross-dataset input while bounding normalized radar outliers."
    frame = process_pose_frame(align_target_frame(crop_target_frame(points)))
    return frame.clamp(-CONFIG['clipping'], CONFIG['clipping'])

# %%
def build_mars_frame_index(file_paths):
    "Create synchronized MARS radar-to-skeleton frame indexes."
    samples = []
    for path in file_paths:
        count = min(len(load_mars_radar_frames_raw(path)), len(load_mars_skeletons_raw(path)))
        samples.extend((path, frame_idx) for frame_idx in range(count))
    return samples

# %%
class MARSPoseValidationDataset(Dataset):
    "MARS validation frames and centered Kinect targets."
    def __init__(self, samples):
        self.samples = samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, frame_idx = self.samples[idx]
        target = normalize_skeleton(load_mars_skeletons_raw(path)[frame_idx])
        return process_pose_frame(load_mars_radar_frames_raw(path)[frame_idx]), target

# %% [markdown]
# # architecture

# %%
def knn(x, k):
    "Find point-neighborhood indexes for SK-DGCNN EdgeConv."
    inner = -2 * torch.matmul(x.transpose(2, 1), x)
    xx = torch.sum(x ** 2, dim=1, keepdim=True)
    distance = -xx - inner - xx.transpose(2, 1)
    return distance.topk(k=k, dim=-1)[1]

# %%
def get_graph_feature(x, k=20):
    "Build EdgeConv features exactly as in MARS training: center minus neighbor."
    batch_size, feature_amount, point_amount = x.shape
    idx = knn(x, k=k)
    idx_base = torch.arange(batch_size, device=x.device).view(-1, 1, 1) * point_amount
    idx = (idx + idx_base).view(-1)
    points = x.transpose(2, 1).contiguous()
    neighbors = points.view(batch_size * point_amount, feature_amount)[idx]
    neighbors = neighbors.view(batch_size, point_amount, k, feature_amount)
    centers = points.view(batch_size, point_amount, 1, feature_amount).repeat(1, 1, k, 1)
    return torch.cat((centers - neighbors, centers), dim=3).permute(0, 3, 1, 2).contiguous()

# %%
class ECALayer(nn.Module):
    "Efficient channel attention layer used by the trained SK-DGCNN."
    def __init__(self):
        super().__init__()
        self.conv = nn.Conv1d(1, 1, kernel_size=CONFIG['eca_kernel_size'], padding=1, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        weights = x.mean(dim=tuple(range(2, x.dim()))).unsqueeze(1)
        weights = self.conv(weights).squeeze(1).view(x.size(0), x.size(1), *([1] * (x.dim() - 2)))
        return x * self.sigmoid(weights)

# %%
class DGCNNSkeletonRegressor(nn.Module):
    "SK-DGCNN regressor matching the MARS pose checkpoint architecture."
    def __init__(self):
        super().__init__()
        self.k = CONFIG['k']
        self.joints = len(SKELETON_JOINT_INDICES)
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(128)
        self.bn4 = nn.BatchNorm1d(CONFIG['emb_dims'])
        self.bn5 = nn.BatchNorm1d(512)
        self.bn6 = nn.BatchNorm1d(self.joints * 128)
        self.conv1 = nn.Sequential(nn.Conv2d(CONFIG['feature_amount'] * 2, 64, 1, bias=False), self.bn1, nn.LeakyReLU(0.2))
        self.conv2 = nn.Sequential(nn.Conv2d(128, 64, 1, bias=False), self.bn2, nn.LeakyReLU(0.2))
        self.conv3 = nn.Sequential(nn.Conv2d(128, 128, 1, bias=False), self.bn3, nn.LeakyReLU(0.2))
        self.conv4 = nn.Sequential(nn.Conv1d(256, CONFIG['emb_dims'], 1, bias=False), self.bn4, nn.LeakyReLU(0.2))
        self.eca1 = ECALayer()
        self.eca2 = ECALayer()
        self.eca3 = ECALayer()
        self.eca4 = ECALayer()
        self.linear1 = nn.Linear(CONFIG['emb_dims'] * 2, 512, bias=False)
        self.linear2 = nn.Linear(512, self.joints * 128, bias=False)
        self.dp1 = nn.Dropout(CONFIG['dropout'])
        self.dp2 = nn.Dropout(CONFIG['dropout'])
        self.x_head = nn.Linear(128, 1)
        self.z_head = nn.Linear(128, 1)

    def forward(self, x):
        batch_size = x.size(0)
        x1 = self.eca1(self.conv1(get_graph_feature(x, self.k))).max(dim=-1)[0]
        x2 = self.eca2(self.conv2(get_graph_feature(x1, self.k))).max(dim=-1)[0]
        x3 = self.eca3(self.conv3(get_graph_feature(x2, self.k))).max(dim=-1)[0]
        x = self.eca4(self.conv4(torch.cat((x1, x2, x3), dim=1)))
        x = torch.cat((F.adaptive_max_pool1d(x, 1).view(batch_size, -1), F.adaptive_avg_pool1d(x, 1).view(batch_size, -1)), dim=1)
        x = self.dp1(F.leaky_relu(self.bn5(self.linear1(x)), negative_slope=0.2))
        x = self.dp2(F.leaky_relu(self.bn6(self.linear2(x)), negative_slope=0.2)).view(batch_size, self.joints, 128)
        return torch.cat((self.x_head(x), self.z_head(x)), dim=2).reshape(batch_size, -1)

# %% [markdown]
# # inference

# %%
def pose_joint_mae(predictions, targets):
    "Compute centered lateral, vertical coordinate MAE in centimeters for every joint."
    errors = (predictions - targets).abs().view(-1, len(SKELETON_JOINT_INDICES), len(SKELETON_COORDINATE_INDICES))
    return errors.mean(dim=(0, 2)) * 100

# %%
def evaluate_pose_checkpoint(checkpoint_path, file_paths):
    "Score one pose checkpoint on centered MARS lateral, vertical skeleton coordinates."
    model = DGCNNSkeletonRegressor().to(DEVICE)
    model.load_state_dict(torch.load(checkpoint_path, map_location=DEVICE, weights_only=True))
    model.eval()
    loader = DataLoader(MARSPoseValidationDataset(build_mars_frame_index(file_paths)), batch_size=CONFIG['batch_size'], shuffle=False)
    predictions = []
    targets = []
    with torch.no_grad():
        for point_cloud, target in loader:
            predictions.append(model(point_cloud.to(DEVICE).permute(0, 2, 1)).cpu())
            targets.append(target)
    joint_maes = pose_joint_mae(torch.cat(predictions), torch.cat(targets))
    return joint_maes.mean().item(), joint_maes

# %%
def load_pose_model(checkpoint_path):
    "Load the paper-compatible MARS SK-DGCNN checkpoint for inference."
    model = DGCNNSkeletonRegressor().to(DEVICE)
    model.load_state_dict(torch.load(checkpoint_path, map_location=DEVICE, weights_only=True))
    model.eval()
    return model

# %%
def dguha_clip_index():
    "List DGUHA source clips with split, clip index, and label."
    samples = []
    for split in ('Train', 'Test'):
        for clip_idx, label in enumerate(load_dguha_labels(split)):
            samples.append((split, clip_idx, label))
    return samples

# %%
def normalized_dguha_feature_summary():
    "Report aligned DGUHA radar distributions in MARS-normalized space."
    frames = []
    for split, clip_idx, _ in dguha_clip_index():
        frames.extend(align_target_frame(crop_target_frame(frame)) for frame in load_dguha_radar_frames_raw(split, clip_idx))
    points = torch.cat(frames, dim=0)
    mean, std = mars_radar_normalization_stats()
    normalized = (points - mean) / std
    clipped = normalized.clamp(-CONFIG['clipping'], CONFIG['clipping'])
    return {
        'before_clipping': {name: {'mean': float(normalized[:, i].mean()), 'std': float(normalized[:, i].std())} for i, name in enumerate(CONFIG['feature_names'])},
        'after_clipping': {name: {'mean': float(clipped[:, i].mean()), 'std': float(clipped[:, i].std())} for i, name in enumerate(CONFIG['feature_names'])},
    }

# %%
def preprocess_dguha_clip(split, clip_idx, label, destination_path, model):
    "Predict and save centered lateral, vertical skeleton frames for one DGUHA clip."
    frames = load_dguha_radar_frames_raw(split, clip_idx)
    predictions = []
    with torch.no_grad():
        for start in range(0, len(frames), CONFIG['batch_size']):
            batch = torch.stack([process_target_frame(frame) for frame in frames[start:start + CONFIG['batch_size']]])
            predictions.append(model(batch.to(DEVICE).permute(0, 2, 1)).cpu())
    skeletons = torch.cat(predictions).view(-1, len(SKELETON_JOINT_INDICES), 2)
    destination_path.parent.mkdir(parents=True, exist_ok=True)
    torch.save(skeletons, destination_path)

# %%
def prepare_skdguha(checkpoint_path, force=False):
    "Rebuild the DGUHA skeleton cache and record its complete pose contract."
    metadata_path = SKDGUHA_ROOT / 'metadata.json'
    signature = {
        'pose_checkpoint': str(checkpoint_path.relative_to(PROJECT_ROOT)),
        'mtime_ns': checkpoint_path.stat().st_mtime_ns,
        'radar_axis_mapping': {'MARS x (lateral)': 'DGUHA y (lateral)', 'MARS y (depth)': 'DGUHA x (depth)', 'MARS z (vertical)': 'DGUHA z (vertical)'},
        'radar_spatial_crop': MARS_RADAR_ROI,
        'radar_frame_alignment': 'translate spatial centroid to MARS training mean',
        'clipping': CONFIG['clipping'],
        'joint_names': list(SKELETON_JOINT_NAMES),
        'coordinates': ['x (lateral)', 'z (vertical)'],
        'center_joint': 'SpineShoulder',
        'activity_class_names': list(DGUHA_ACTIVITY_CLASS_NAMES),
    }
    existing = json.loads(metadata_path.read_text()) if metadata_path.exists() else {}
    if all(existing.get(key) == value for key, value in signature.items()) and not force:
        print(f'Reusing SKDGUHA generated with {checkpoint_path.name}')
        return
    shutil.rmtree(SKDGUHA_ROOT / 'Train', ignore_errors=True)
    shutil.rmtree(SKDGUHA_ROOT / 'Test', ignore_errors=True)
    model = load_pose_model(checkpoint_path)
    sources = dguha_clip_index()
    for index, (split, clip_idx, label) in enumerate(sources, start=1):
        class_name = DGUHA_ACTIVITY_CLASS_NAMES[label]
        destination = SKDGUHA_ROOT / split / class_name / f'{clip_idx:04d}.pt'
        preprocess_dguha_clip(split, clip_idx, label, destination, model)
        if index % 20 == 0 or index == len(sources):
            print(f'Preprocessed {index}/{len(sources)} clips')
    train_files, _ = split_mars_file_paths()
    train_mae, joint_maes = evaluate_pose_checkpoint(checkpoint_path, train_files)
    confidence = 0.85 - 0.1 * torch.log(joint_maes / joint_maes.mean())
    metadata = dict(signature)
    metadata['mars_train_mae_cm'] = train_mae
    metadata['mars_train_joint_mae_cm'] = dict(zip(SKELETON_JOINT_NAMES, joint_maes.tolist()))
    metadata['joint_confidence_scores'] = confidence.tolist()
    metadata['normalized_dguha_feature_summary'] = normalized_dguha_feature_summary()
    SKDGUHA_ROOT.mkdir(parents=True, exist_ok=True)
    metadata_path.write_text(json.dumps(metadata, indent=2))
    print(f'SKDGUHA rebuilt with {checkpoint_path.name}')

# %%
_, mars_valid_files = split_mars_file_paths()
validation_mae, validation_joint_maes = evaluate_pose_checkpoint(CHECKPOINT_PATH, mars_valid_files)
print(f'MARS validation lateral,vertical MAE: {validation_mae:.4f} cm')
print(dict(zip(SKELETON_JOINT_NAMES, validation_joint_maes.tolist())))
print(normalized_dguha_feature_summary())
prepare_skdguha(CHECKPOINT_PATH, force=True)
print(json.loads((SKDGUHA_ROOT / 'metadata.json').read_text()))
# Out:
# MARS validation lateral,vertical MAE: 11.7221 cm
# {'SpineBase': 8.196722984313965, 'SpineMid': 3.563122034072876, 'Neck': 1.006017804145813, 'Head': 3.3683266639709473, 'ShoulderLeft': 4.074911117553711, 'ElbowLeft': 10.725519180297852, 'WristLeft': 15.243446350097656, 'ShoulderRight': 3.4146502017974854, 'ElbowRight': 10.089348793029785, 'WristRight': 14.754382133483887, 'HipLeft': 8.982800483703613, 'KneeLeft': 17.418291091918945, 'AnkleLeft': 22.276384353637695, 'FootLeft': 23.94504737854004, 'HipRight': 8.707716941833496, 'KneeRight': 17.505199432373047, 'AnkleRight': 23.86244773864746, 'FootRight': 25.326671600341797, 'SpineShoulder': 0.2597592771053314}
# {'before_clipping': {'x': {'mean': 6.204924574149118e-09, 'std': 0.795761227607727}, 'y': {'mean': 1.8115239308613695e-09, 'std': 3.905747413635254}, 'z': {'mean': 1.6271853864324726e-09, 'std': 0.8584225177764893}, 'velocity': {'mean': 0.0008399059879593551, 'std': 0.0}, 'intensity': {'mean': -0.6910399794578552, 'std': 5.960465188081798e-08}}, 'after_clipping': {'x': {'mean': 2.5102401195908897e-05, 'std': 0.7955483198165894}, 'y': {'mean': 0.04331795871257782, 'std': 3.147271156311035}, 'z': {'mean': 4.204608558211476e-06, 'std': 0.8584022521972656}, 'velocity': {'mean': 0.0008399059879593551, 'std': 0.0}, 'intensity': {'mean': -0.6910399794578552, 'std': 5.960465188081798e-08}}}
# Preprocessed 20/768 clips
# Preprocessed 40/768 clips
# Preprocessed 60/768 clips
# Preprocessed 80/768 clips
# Preprocessed 100/768 clips
# Preprocessed 120/768 clips
# Preprocessed 140/768 clips
# Preprocessed 160/768 clips
# Preprocessed 180/768 clips
# Preprocessed 200/768 clips
# Preprocessed 220/768 clips
# Preprocessed 240/768 clips
# Preprocessed 260/768 clips
# Preprocessed 280/768 clips
# Preprocessed 300/768 clips
# Preprocessed 320/768 clips
# Preprocessed 340/768 clips
# Preprocessed 360/768 clips
# Preprocessed 380/768 clips
# Preprocessed 400/768 clips
# Preprocessed 420/768 clips
# Preprocessed 440/768 clips
# Preprocessed 460/768 clips
# Preprocessed 480/768 clips
# Preprocessed 500/768 clips
# Preprocessed 520/768 clips
# Preprocessed 540/768 clips
# Preprocessed 560/768 clips
# Preprocessed 580/768 clips
# Preprocessed 600/768 clips
# Preprocessed 620/768 clips
# Preprocessed 640/768 clips
# Preprocessed 660/768 clips
# Preprocessed 680/768 clips
# Preprocessed 700/768 clips
# Preprocessed 720/768 clips
# Preprocessed 740/768 clips
# Preprocessed 760/768 clips
# Preprocessed 768/768 clips
# SKDGUHA rebuilt with checkpoint_133.pt
# {'pose_checkpoint': 'datasets/SKDGUHA/checkpoint_133.pt', 'mtime_ns': 1779800557689805910, 'radar_axis_mapping': {'MARS x (lateral)': 'DGUHA y (lateral)', 'MARS y (depth)': 'DGUHA x (depth)', 'MARS z (vertical)': 'DGUHA z (vertical)'}, 'radar_spatial_crop': {'x': [-1.0, 1.0], 'y': [0.0, 3.0], 'z': [-1.0, 1.0]}, 'radar_frame_alignment': 'translate spatial centroid to MARS training mean', 'clipping': 4.0, 'joint_names': ['SpineBase', 'SpineMid', 'Neck', 'Head', 'ShoulderLeft', 'ElbowLeft', 'WristLeft', 'ShoulderRight', 'ElbowRight', 'WristRight', 'HipLeft', 'KneeLeft', 'AnkleLeft', 'FootLeft', 'HipRight', 'KneeRight', 'AnkleRight', 'FootRight', 'SpineShoulder'], 'coordinates': ['x (lateral)', 'z (vertical)'], 'center_joint': 'SpineShoulder', 'activity_class_names': ['running', 'jumping', 'sitting_down_and_standing_up', 'both_upper_limb_extension', 'falling_forward', 'right_limb_extension', 'left_limb_extension'], 'mars_train_mae_cm': 2.9636878967285156, 'mars_train_joint_mae_cm': {'SpineBase': 1.232799768447876, 'SpineMid': 0.5437830686569214, 'Neck': 0.3837442994117737, 'Head': 0.9922459721565247, 'ShoulderLeft': 0.9039871692657471, 'ElbowLeft': 3.6158549785614014, 'WristLeft': 6.72009801864624, 'ShoulderRight': 0.8242326974868774, 'ElbowRight': 3.666846752166748, 'WristRight': 7.114578723907471, 'HipLeft': 1.3179597854614258, 'KneeLeft': 3.3952813148498535, 'AnkleLeft': 5.093238830566406, 'FootLeft': 5.5022735595703125, 'HipRight': 1.2647440433502197, 'KneeRight': 3.303114414215088, 'AnkleRight': 4.926990509033203, 'FootRight': 5.251926422119141, 'SpineShoulder': 0.2563712000846863}, 'joint_confidence_scores': [0.937714695930481, 1.019563913345337, 1.054421305656433, 0.9594218730926514, 0.9687374830245972, 0.8301106095314026, 0.7681331634521484, 0.9779736995697021, 0.8287102580070496, 0.762428879737854, 0.9310349822044373, 0.8364048004150391, 0.7958520650863647, 0.7881273031234741, 0.9351564645767212, 0.8391568660736084, 0.7991706132888794, 0.7927839756011963, 1.0947563648223877], 'normalized_dguha_feature_summary': {'before_clipping': {'x': {'mean': 6.204924574149118e-09, 'std': 0.795761227607727}, 'y': {'mean': 1.8115239308613695e-09, 'std': 3.905747413635254}, 'z': {'mean': 1.6271853864324726e-09, 'std': 0.8584225177764893}, 'velocity': {'mean': 0.0008399059879593551, 'std': 0.0}, 'intensity': {'mean': -0.6910399794578552, 'std': 5.960465188081798e-08}}, 'after_clipping': {'x': {'mean': 2.5102401195908897e-05, 'std': 0.7955483198165894}, 'y': {'mean': 0.04331795871257782, 'std': 3.147271156311035}, 'z': {'mean': 4.204608558211476e-06, 'std': 0.8584022521972656}, 'velocity': {'mean': 0.0008399059879593551, 'std': 0.0}, 'intensity': {'mean': -0.6910399794578552, 'std': 5.960465188081798e-08}}}}
